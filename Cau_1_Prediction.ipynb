# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/LDS8_K270_ONLINE_DoThiPhuong/LDS8_K270_DoThiPhuong_Cuoi_ky/Cau_1'
# Out:
# /content/gdrive/My Drive/LDS8_K270_ONLINE_DoThiPhuong/LDS8_K270_DoThiPhuong_Cuoi_ky/Cau_1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
# # load the model from disk
# Returns a compiled model identical to the previous one
from tensorflow.keras.models import load_model
model = load_model('house_price.h5')

# %%
df = pd.read_csv('MELBOURNE_HOUSE_PRICES_LESS.csv')

# %%
df = df[['Suburb', 'Rooms', 'Type', 'Method', 'Distance', 'Price']]

# %%
df1 = df[df.Price.isnull()]
df1 = df1[['Suburb', 'Rooms', 'Type', 'Method', 'Distance']]
df1.shape
# Out:
# (14590, 5)

# %%
df1.head()
# Out:
#             Suburb  Rooms Type Method  Distance
# 8        Albanvale      6    h     PI      14.0
# 15  Altona Meadows      4    h     SN      15.5
# 24       Ashburton      4    h      S      10.2
# 29         Attwood      4    h     SN      16.5
# 38    Balwyn North      3    h     SP       9.7

# %%
X_pred = df1.values

# %%
import pickle
import numpy as np
ctfile = 'ColumnTransformer.pkl'
file = open(ctfile,'rb')
ct = pickle.load(file)

# %%
y_pred = model.predict(ct.transform(X_pred))

# %%
y_pred[:5]
# Out:
# array([[ 854362.25],
#        [ 592378.9 ],
#        [1868162.4 ],
#        [ 592064.25],
#        [1610643.1 ]], dtype=float32)
